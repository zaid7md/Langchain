# %%
import os 
from dotenv import load_dotenv 
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama
# Load .env if present
load_dotenv(override='True')

if os.getenv("LLM_API_KEY"):
    print("Api key exists")
else:
    print("LLM_API_KEY not found")
# Out:
# Api key exists

# %%
from langchain.tools import tool

@tool
def multiply(a: int, b: int) -> int:
    """Multiply two numbers"""
    return a * b

# %%
llm1 = ChatOpenAI(model="gpt-4o-mini", temperature=0)
llm2 = ChatOllama(model="llama3.1:8b", temperature=0)

# %%
from langchain_core.prompts import ChatPromptTemplate

# %%
prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful chatbot assistance for a medical insurance company"),
    ("user", /"")
])
