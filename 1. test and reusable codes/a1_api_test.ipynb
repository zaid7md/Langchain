# %%
from dotenv import load_dotenv
import os 
from openai import OpenAI

load_dotenv(override=True)

api_key = os.getenv("LLM_API_KEY")

if not api_key:
    print("LLM_API_KEY not found")
else:
    print("Api key exists \n")

client = OpenAI(base_url=os.getenv("BASE_URL"),
    api_key=api_key,
)

try:
    response = client.responses.create(
        model="openai/gpt-4o-mini",  # model name as required by gateway
        input="Explain LangChain in one sentence."
    )

    print(response.output_text)

    print('API is working')

except Exception as error:
    print("Error occurred:")
    print(error)
# Out:
# Api key exists
#
# LangChain is a framework that simplifies the development of applications using large language models by providing tools for integrating various sources of data, managing conversational context, and chaining together different components for enhanced functionality.
# API is working
