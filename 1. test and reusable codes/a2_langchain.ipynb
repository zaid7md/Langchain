# %%
from dotenv import load_dotenv
import os 
from langchain_openai import ChatOpenAI
# from langchain_google_gemini import ChatGoogleGemini
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

load_dotenv(override=True)

api_key = os.getenv("LLM_API_KEY")
if not api_key:
    print("LLM_API_KEY not found")
else:
    print("Api key exists")
# Out:
# Api key exists

# %%
from langsmith import Client

client = Client(
    api_url="https://api.smith.langchain.com"
)

print(client)
# Out:
# Client (API URL: https://api.smith.langchain.com)

# %%
llm = ChatOpenAI(model='openai/gpt-4o' , temperature=0 , api_key=os.getenv("LLM_API_KEY") , base_url=os.getenv("BASE_URL")
)

# %%
response = llm.invoke("Hows the day today in sector 62 noida(answer in one word)")

# %%
print(response.content)
# Out:
# Uncertain.

# %%
print(os.getenv("LANGSMITH_ENDPOINT"))
# Out:
# https://api.smith.langchain.com
